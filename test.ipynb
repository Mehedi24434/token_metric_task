# %%
import requests

URL = "https://api.hyperliquid.xyz/info"

payload = {
    "type": "allMids"
}

resp = requests.post(URL, json=payload, timeout=10)
resp.raise_for_status()

mids = resp.json()

print(f"BTC mid price: {mids.get('BTC')}")
print(f"ETH mid price: {mids.get('ETH')}")
# Out:
# BTC mid price: 88337.5
# ETH mid price: 2939.95

# %% [markdown]
# ### Fetch prices

# %%
import requests

def fetch_mids():
    url = "https://api.hyperliquid.xyz/info"
    payload = {"type": "allMids"}
    r = requests.post(url, json=payload)
    r.raise_for_status()
    return r.json()

# %% [markdown]
# ### Maintain rolling price history

# %%
from collections import deque

price_history = {
    "BTC": deque(maxlen=50),
    "ETH": deque(maxlen=50)
}

# %% [markdown]
# ### Update Prices

# %%
mids = fetch_mids()

price_history["BTC"].append(float(mids["BTC"]))
price_history["ETH"].append(float(mids["ETH"]))

# %% [markdown]
# ### Compute SMA

# %%
import numpy as np

def compute_sma(prices):
    if len(prices) == 0:
        return None
    return np.mean(prices)

# %% [markdown]
# ### Signal

# %%
def generate_signal(price, sma):
    if sma is None:
        return 0
    return 1 if price > sma else 0

# %% [markdown]
# ### Compute signals for BTC & ETH

# %%
signals = {}

for asset in ["BTC", "ETH"]:
    price = price_history[asset][-1]
    sma = compute_sma(price_history[asset])
    signals[asset] = generate_signal(price, sma)

signals
# Out:
# {'BTC': 0, 'ETH': 0}

# %% [markdown]
# ### Trade Engine

# %%
state = {
    "BTC": {"position": 0, "entry_price": None, "pnl": 0.0, "trades": 0},
    "ETH": {"position": 0, "entry_price": None, "pnl": 0.0, "trades": 0},
}

# %%
def execute_trade(asset, target_pos, price, state, max_position_usd):
    current_pos = state[asset]["position"]
    
    if current_pos == target_pos:
        return None  # no trade
    
    # position size in units
    size = max_position_usd / price
    
    trade = {
        "asset": asset,
        "price": price,
        "direction": "BUY" if target_pos == 1 else "SELL",
        "size": size
    }
    
    # Enter long
    if current_pos == 0 and target_pos == 1:
        state[asset]["position"] = 1
        state[asset]["entry_price"] = price
        state[asset]["trades"] += 1
    
    # Exit long
    elif current_pos == 1 and target_pos == 0:
        entry = state[asset]["entry_price"]
        pnl = (price - entry) * size
        state[asset]["pnl"] += pnl
        state[asset]["position"] = 0
        state[asset]["entry_price"] = None
        state[asset]["trades"] += 1
        trade["realized_pnl"] = pnl
    
    return trade

# %% [markdown]
# ### Run Execution

# %%
trades = []

limits = {"BTC": 5000, "ETH": 3000}

for asset in ["BTC", "ETH"]:
    trade = execute_trade(
        asset=asset,
        target_pos=signals[asset],
        price=price_history[asset][-1],
        state=state,
        max_position_usd=limits[asset]
    )
    if trade:
        trades.append(trade)

trades
# Out:
# []

# %% [markdown]
# ### Logging

# %%
import pandas as pd
from datetime import datetime

log_rows = []

def log_trade(trade, signal, position):
    row = {
        "timestamp": datetime.utcnow().isoformat(),
        "asset": trade["asset"],
        "price": trade["price"],
        "signal": signal,
        "direction": trade["direction"],
        "size": trade["size"],
        "position": position,
        "realized_pnl": trade.get("realized_pnl", 0.0),
    }
    log_rows.append(row)

# %%
from datetime import datetime
import time

def status_print(asset, price, sma, signal, position, trade=None):
    ts = datetime.utcnow().strftime("%H:%M:%S")
    
    sma_str = f"{sma:.2f}" if sma is not None else "NA"
    
    msg = (
        f"[{ts}] {asset} | "
        f"Price: {price:.2f} | "
        f"SMA: {sma_str} | "
        f"Signal: {'LONG' if signal == 1 else 'FLAT'} | "
        f"Position: {position}"
    )
    
    if trade:
        msg += f" | TRADE: {trade['direction']} {trade['size']:.4f}"
    
    print(msg)

# %% [markdown]
# ### Log executed trades

# %%
for trade in trades:
    asset = trade["asset"]
    log_trade(
        trade=trade,
        signal=signals[asset],
        position=state[asset]["position"]
    )

pd.DataFrame(log_rows)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Wrap in a loop (scheduler)

# %%
for _ in range(10):
    mids = fetch_mids()
    
    for asset in ["BTC", "ETH"]:
        price_history[asset].append(float(mids[asset]))
    
    for asset in ["BTC", "ETH"]:
        price = price_history[asset][-1]
        sma = compute_sma(price_history[asset])
        signal = generate_signal(price, sma)
        
        trade = execute_trade(
            asset, signal, price, state, limits[asset]
        )
        
        status_print(
            asset=asset,
            price=price,
            sma=sma,
            signal=signal,
            position=state[asset]["position"],
            trade=trade
        )
        
        if trade:
            log_trade(trade, signal, state[asset]["position"])
    
    print("-" * 80)
    time.sleep(60)
# Out:
# [15:47:59] BTC | Price: 88337.50 | SMA: 88337.50 | Signal: FLAT | Position: 0
# [15:47:59] ETH | Price: 2939.05 | SMA: 2939.50 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:48:59] BTC | Price: 88366.50 | SMA: 88347.17 | Signal: LONG | Position: 1 | TRADE: BUY 0.0566
# [15:48:59] ETH | Price: 2942.85 | SMA: 2940.62 | Signal: LONG | Position: 1 | TRADE: BUY 1.0194
# --------------------------------------------------------------------------------
# [15:49:59] BTC | Price: 88284.50 | SMA: 88331.50 | Signal: FLAT | Position: 0 | TRADE: SELL 0.0566
# [15:49:59] ETH | Price: 2939.95 | SMA: 2940.45 | Signal: FLAT | Position: 0 | TRADE: SELL 1.0204
# --------------------------------------------------------------------------------
# [15:51:00] BTC | Price: 87853.00 | SMA: 88235.80 | Signal: FLAT | Position: 0
# [15:51:00] ETH | Price: 2920.35 | SMA: 2936.43 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:52:00] BTC | Price: 87805.50 | SMA: 88164.08 | Signal: FLAT | Position: 0
# [15:52:00] ETH | Price: 2918.05 | SMA: 2933.37 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:53:00] BTC | Price: 87604.50 | SMA: 88084.14 | Signal: FLAT | Position: 0
# [15:53:00] ETH | Price: 2906.85 | SMA: 2929.58 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:54:01] BTC | Price: 87677.50 | SMA: 88033.31 | Signal: FLAT | Position: 0
# [15:54:01] ETH | Price: 2907.35 | SMA: 2926.80 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:55:01] BTC | Price: 87596.50 | SMA: 87984.78 | Signal: FLAT | Position: 0
# [15:55:01] ETH | Price: 2905.75 | SMA: 2924.46 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:56:01] BTC | Price: 87489.50 | SMA: 87935.25 | Signal: FLAT | Position: 0
# [15:56:01] ETH | Price: 2909.15 | SMA: 2922.93 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [15:57:02] BTC | Price: 87477.50 | SMA: 87893.64 | Signal: FLAT | Position: 0
# [15:57:02] ETH | Price: 2907.25 | SMA: 2921.50 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Robust

# %%
import time
import requests
import numpy as np
import pandas as pd
from collections import deque
from datetime import datetime

# %%
ASSETS = {
"BTC": {
"max_position_usd": 5000
},
"ETH": {
"max_position_usd": 3000
}
}

SMA_WINDOW = 100
EMA_WINDOW = 100
VOL_WINDOW = 50
VOL_RSI_WINDOW = 14
VOLUME_PERCENTILE = 70

TAKE_PROFIT_PCT = 0.003 # 0.30%
STOP_LOSS_PCT = 0.002 # 0.20%

MAX_TRADES_PER_ASSET = 10
MAX_DRAWDOWN_PCT = 2.0
STARTING_CAPITAL = 10000

LOOP_INTERVAL = 60 # seconds

# %%
price_history = {
    "BTC": deque(maxlen=SMA_WINDOW),
    "ETH": deque(maxlen=SMA_WINDOW)
}

vol_history = {
    "BTC": deque(maxlen=VOL_WINDOW),
    "ETH": deque(maxlen=VOL_WINDOW)
}

volume_history = {
    "BTC": deque(maxlen=100),
    "ETH": deque(maxlen=100)
}

state = {
    "BTC": {"position": 0, "entry_price": None, "pnl": 0.0, "trades": 0},
    "ETH": {"position": 0, "entry_price": None, "pnl": 0.0, "trades": 0}
}

log_rows = []


def fetch_mids():
    url = "https://api.hyperliquid.xyz/info"
    payload = {"type": "allMids"}
    r = requests.post(url, json=payload, timeout=10)
    r.raise_for_status()
    return r.json()


def fetch_orderbook(asset):
    url = "https://api.hyperliquid.xyz/info"
    payload = {
        "type": "l2Book",
        "coin": asset
    }
    r = requests.post(url, json=payload, timeout=10)
    r.raise_for_status()
    return r.json()


def fetch_recent_volume(asset, lookback_seconds=60):
    url = "https://api.hyperliquid.xyz/info"
    payload = {
        "type": "recentTrades",
        "coin": asset
    }
    r = requests.post(url, json=payload, timeout=10)
    r.raise_for_status()
    trades = r.json()

    now = time.time() * 1000  # ms
    vol = 0.0
    for t in trades:
        if now - t["time"] <= lookback_seconds * 1000:
            vol += float(t["sz"])
    return vol

# %%
## =========================
## INDICATORS
## =========================

def compute_sma(prices):
    return np.mean(prices) if len(prices) > 0 else None

def compute_ema(prices, window=100):
    if len(prices) == 0:
        return None
    alpha = 2 / (window + 1)
    ema = prices[0]
    for p in prices[1:]:
        ema = alpha * p + (1 - alpha) * ema
    return ema

def compute_volatility(prices):
    if len(prices) < 2:
        return None
    returns = np.diff(prices) / prices[:-1]
    return np.std(returns)

def compute_rsi(series, window=14):
    if len(series) < window + 1:
        return None
    deltas = np.diff(series)
    gains = np.maximum(deltas, 0)
    losses = np.maximum(-deltas, 0)
    avg_gain = np.mean(gains[-window:])
    avg_loss = np.mean(losses[-window:])
    if avg_loss == 0:
        return 100.0
    rs = avg_gain / avg_loss
    return 100 - (100 / (1 + rs))

def volume_filter(current_vol, history, percentile=70):
    if len(history) < 10:
        return False
    threshold = np.percentile(history, percentile)
    return current_vol > threshold

# %%
def generate_signal(price, sma, ema, vol_rsi, vol_ok):
    trend_ok = price > sma and price > ema
    volatility_ok = vol_rsi is not None and vol_rsi > 70
    return 1 if (trend_ok and volatility_ok and vol_ok) else 0

# %%
def estimate_execution_price(orderbook, side, order_size):
    """
    side: 'BUY' or 'SELL'
    order_size: base asset size
    """
    levels = orderbook["levels"]
    
    # Hyperliquid: asks are positive px for BUY, bids for SELL
    book = levels["asks"] if side == "BUY" else levels["bids"]

    remaining = order_size
    cost = 0.0
    filled = 0.0

    for lvl in book:
        price = float(lvl["px"])
        size = float(lvl["sz"])

        take = min(size, remaining)
        cost += take * price
        filled += take
        remaining -= take

        if remaining <= 0:
            break

    if filled == 0:
        return None

    return cost / filled


def execute_trade(asset, target_pos, mid_price, state, max_position_usd):
    current_pos = state[asset]["position"]
    size = max_position_usd / mid_price

    orderbook = fetch_orderbook(asset)

    # ENTRY
    if current_pos == 0 and target_pos == 1:
        exec_price = estimate_execution_price(orderbook, "BUY", size)
        if exec_price is None:
            return None

        state[asset]["position"] = 1
        state[asset]["entry_price"] = exec_price
        state[asset]["trades"] += 1

        return {
            "asset": asset,
            "mid_price": mid_price,
            "price": exec_price,
            "direction": "BUY",
            "size": size,
            "slippage": exec_price - mid_price
        }

    # EXIT
    if current_pos == 1:
        entry = state[asset]["entry_price"]
        pnl_pct = (mid_price - entry) / entry

        exit_reason = None
        if pnl_pct >= TAKE_PROFIT_PCT:
            exit_reason = "TAKE_PROFIT"
        elif pnl_pct <= -STOP_LOSS_PCT:
            exit_reason = "STOP_LOSS"
        elif target_pos == 0:
            exit_reason = "TREND_EXIT"

        if exit_reason:
            exec_price = estimate_execution_price(orderbook, "SELL", size)
            if exec_price is None:
                return None

            pnl = (exec_price - entry) * size
            state[asset]["pnl"] += pnl
            state[asset]["position"] = 0
            state[asset]["entry_price"] = None
            state[asset]["trades"] += 1

            return {
                "asset": asset,
                "mid_price": mid_price,
                "price": exec_price,
                "direction": "SELL",
                "size": size,
                "realized_pnl": pnl,
                "exit_reason": exit_reason,
                "slippage": exec_price - mid_price
            }

    return None

# %%
def log_trade(trade, signal, position):
    log_rows.append({
        "timestamp": datetime.utcnow().isoformat(),
        "asset": trade["asset"],
        "mid_price": trade["mid_price"],
        "exec_price": trade["price"],
        "slippage": trade.get("slippage", 0.0),
        "signal": signal,
        "direction": trade["direction"],
        "size": trade["size"],
        "position": position,
        "realized_pnl": trade.get("realized_pnl", 0.0),
        "exit_reason": trade.get("exit_reason", "")
    })


def status_print(asset, price, sma, ema, vol_rsi, volume, signal, position, trade=None):
    ts = datetime.utcnow().strftime("%H:%M:%S")

    sma_str = f"{sma:.2f}" if sma is not None else "NA"
    ema_str = f"{ema:.2f}" if ema is not None else "NA"
    vol_rsi_str = f"{vol_rsi:.1f}" if vol_rsi is not None else "NA"
    vol_str = f"{volume:.2f}" if volume is not None else "NA"

    msg = (
        f"[{ts}] {asset} | "
        f"Mid: {price:.2f} | "
        f"SMA: {sma_str} | EMA: {ema_str} | "
        f"Vol_RSI: {vol_rsi_str} | "
        f"Vol: {vol_str} | "
        f"Signal: {'LONG' if signal else 'FLAT'} | "
        f"Position: {position}"
    )

    if trade:
        exec_px = trade.get("price")
        slip = trade.get("slippage", 0.0)
        reason = trade.get("exit_reason", "")

        msg += (
            f" | TRADE: {trade['direction']} "
            f"@ {exec_px:.2f} "
            f"(slip {slip:.2f})"
        )

        if reason:
            msg += f" [{reason}]"

    print(msg)

# %%
## =========================
## RISK CONTROL
## =========================

def drawdown_exceeded(state):
    total_pnl = sum(v["pnl"] for v in state.values())
    return total_pnl < -STARTING_CAPITAL * MAX_DRAWDOWN_PCT / 100

# %%
while True:
    mids = fetch_mids()

    for asset in ASSETS:
        price = float(mids[asset])
        price_history[asset].append(price)

        vol = compute_volatility(list(price_history[asset]))
        if vol is not None:
            vol_history[asset].append(vol)

        real_vol = fetch_recent_volume(asset)
        volume_history[asset].append(real_vol)


        sma = compute_sma(price_history[asset])
        ema = compute_ema(list(price_history[asset]))
        vol_rsi = compute_rsi(list(vol_history[asset]))
        vol_ok = volume_filter(volume_history[asset][-1], volume_history[asset])

        signal = generate_signal(price, sma, ema, vol_rsi, vol_ok)

        trade = execute_trade(
            asset, signal, price, state, ASSETS[asset]["max_position_usd"]
        )

        status_print(
            asset=asset,
            price=price,
            sma=sma,
            ema=ema,
            vol_rsi=vol_rsi,
            volume=real_vol,
            signal=signal,
            position=state[asset]["position"],
            trade=trade
        )


        if trade:
            log_trade(trade, signal, state[asset]["position"])

    if drawdown_exceeded(state):
        print("Drawdown limit hit. Stopping.")
        break

    print("-" * 80)
    time.sleep(LOOP_INTERVAL)
# Out:
# [17:37:53] BTC | Mid: 86740.50 | SMA: 86740.50 | EMA: 86740.50 | Vol_RSI: NA | Vol: 0.00 | Signal: FLAT | Position: 0
# [17:37:53] ETH | Mid: 2863.55 | SMA: 2863.55 | EMA: 2863.55 | Vol_RSI: NA | Vol: 118.45 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:38:54] BTC | Mid: 86715.50 | SMA: 86728.00 | EMA: 86740.00 | Vol_RSI: NA | Vol: 0.12 | Signal: FLAT | Position: 0
# [17:38:55] ETH | Mid: 2861.15 | SMA: 2862.35 | EMA: 2863.50 | Vol_RSI: NA | Vol: 1.29 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:39:56] BTC | Mid: 86577.50 | SMA: 86677.83 | EMA: 86736.79 | Vol_RSI: NA | Vol: 1.53 | Signal: FLAT | Position: 0
# [17:39:57] ETH | Mid: 2854.55 | SMA: 2859.75 | EMA: 2863.33 | Vol_RSI: NA | Vol: 40.08 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:40:58] BTC | Mid: 86554.50 | SMA: 86647.00 | EMA: 86733.18 | Vol_RSI: NA | Vol: 0.06 | Signal: FLAT | Position: 0
# [17:40:59] ETH | Mid: 2853.75 | SMA: 2858.25 | EMA: 2863.14 | Vol_RSI: NA | Vol: 8.84 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:42:00] BTC | Mid: 86465.50 | SMA: 86610.70 | EMA: 86727.88 | Vol_RSI: NA | Vol: 0.32 | Signal: FLAT | Position: 0
# [17:42:01] ETH | Mid: 2854.25 | SMA: 2857.45 | EMA: 2862.96 | Vol_RSI: NA | Vol: 2.77 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:43:03] BTC | Mid: 86467.50 | SMA: 86586.83 | EMA: 86722.72 | Vol_RSI: NA | Vol: 0.12 | Signal: FLAT | Position: 0
# [17:43:04] ETH | Mid: 2852.45 | SMA: 2856.62 | EMA: 2862.75 | Vol_RSI: NA | Vol: 4.82 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:44:05] BTC | Mid: 86445.50 | SMA: 86566.64 | EMA: 86717.23 | Vol_RSI: NA | Vol: 0.12 | Signal: FLAT | Position: 0
# [17:44:05] ETH | Mid: 2850.15 | SMA: 2855.69 | EMA: 2862.50 | Vol_RSI: NA | Vol: 33.23 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:45:06] BTC | Mid: 86318.50 | SMA: 86535.62 | EMA: 86709.34 | Vol_RSI: NA | Vol: 0.00 | Signal: FLAT | Position: 0
# [17:45:07] ETH | Mid: 2846.85 | SMA: 2854.59 | EMA: 2862.19 | Vol_RSI: NA | Vol: 1.61 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:46:08] BTC | Mid: 86252.50 | SMA: 86504.17 | EMA: 86700.29 | Vol_RSI: NA | Vol: 0.00 | Signal: FLAT | Position: 0
# [17:46:08] ETH | Mid: 2844.05 | SMA: 2853.42 | EMA: 2861.83 | Vol_RSI: NA | Vol: 40.50 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:47:10] BTC | Mid: 86387.00 | SMA: 86492.45 | EMA: 86694.09 | Vol_RSI: NA | Vol: 3.42 | Signal: FLAT | Position: 0
# [17:47:10] ETH | Mid: 2849.25 | SMA: 2853.00 | EMA: 2861.58 | Vol_RSI: NA | Vol: 15.85 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:48:11] BTC | Mid: 86366.50 | SMA: 86481.00 | EMA: 86687.60 | Vol_RSI: NA | Vol: 0.00 | Signal: FLAT | Position: 0
# [17:48:12] ETH | Mid: 2848.05 | SMA: 2852.55 | EMA: 2861.32 | Vol_RSI: NA | Vol: 9.29 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:49:13] BTC | Mid: 86402.50 | SMA: 86474.46 | EMA: 86681.95 | Vol_RSI: NA | Vol: 0.14 | Signal: FLAT | Position: 0
# [17:49:14] ETH | Mid: 2849.95 | SMA: 2852.33 | EMA: 2861.09 | Vol_RSI: NA | Vol: 1.07 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:50:15] BTC | Mid: 86534.50 | SMA: 86479.08 | EMA: 86679.03 | Vol_RSI: NA | Vol: 0.28 | Signal: FLAT | Position: 0
# [17:50:15] ETH | Mid: 2854.75 | SMA: 2852.52 | EMA: 2860.97 | Vol_RSI: NA | Vol: 6.54 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:51:16] BTC | Mid: 86539.50 | SMA: 86483.39 | EMA: 86676.27 | Vol_RSI: NA | Vol: 0.06 | Signal: FLAT | Position: 0
# [17:51:17] ETH | Mid: 2854.65 | SMA: 2852.67 | EMA: 2860.84 | Vol_RSI: NA | Vol: 8.87 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:52:18] BTC | Mid: 86503.50 | SMA: 86484.73 | EMA: 86672.85 | Vol_RSI: NA | Vol: 0.52 | Signal: FLAT | Position: 0
# [17:52:19] ETH | Mid: 2854.65 | SMA: 2852.80 | EMA: 2860.72 | Vol_RSI: NA | Vol: 1.21 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:53:20] BTC | Mid: 86459.50 | SMA: 86483.16 | EMA: 86668.62 | Vol_RSI: 79.1 | Vol: 0.55 | Signal: FLAT | Position: 0
# [17:53:20] ETH | Mid: 2852.65 | SMA: 2852.79 | EMA: 2860.56 | Vol_RSI: 77.5 | Vol: 0.44 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:54:21] BTC | Mid: 86351.50 | SMA: 86475.41 | EMA: 86662.34 | Vol_RSI: 63.3 | Vol: 0.15 | Signal: FLAT | Position: 0
# [17:54:22] ETH | Mid: 2849.05 | SMA: 2852.57 | EMA: 2860.33 | Vol_RSI: 62.7 | Vol: 2.10 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:55:23] BTC | Mid: 86312.50 | SMA: 86466.36 | EMA: 86655.42 | Vol_RSI: 63.8 | Vol: 0.43 | Signal: FLAT | Position: 0
# [17:55:23] ETH | Mid: 2846.95 | SMA: 2852.26 | EMA: 2860.06 | Vol_RSI: 56.9 | Vol: 3.69 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:56:25] BTC | Mid: 86370.50 | SMA: 86461.32 | EMA: 86649.78 | Vol_RSI: 69.4 | Vol: 0.10 | Signal: FLAT | Position: 0
# [17:56:25] ETH | Mid: 2848.95 | SMA: 2852.09 | EMA: 2859.84 | Vol_RSI: 53.4 | Vol: 1.48 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:57:26] BTC | Mid: 86331.50 | SMA: 86454.82 | EMA: 86643.47 | Vol_RSI: 65.9 | Vol: 0.07 | Signal: FLAT | Position: 0
# [17:57:27] ETH | Mid: 2846.25 | SMA: 2851.79 | EMA: 2859.58 | Vol_RSI: 58.2 | Vol: 31.23 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:58:28] BTC | Mid: 86411.50 | SMA: 86452.76 | EMA: 86638.88 | Vol_RSI: 69.7 | Vol: 0.00 | Signal: FLAT | Position: 0
# [17:58:28] ETH | Mid: 2849.55 | SMA: 2851.69 | EMA: 2859.38 | Vol_RSI: 64.6 | Vol: 5.21 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [17:59:29] BTC | Mid: 86348.50 | SMA: 86448.02 | EMA: 86633.13 | Vol_RSI: 66.5 | Vol: 0.20 | Signal: FLAT | Position: 0
# [17:59:30] ETH | Mid: 2845.75 | SMA: 2851.42 | EMA: 2859.11 | Vol_RSI: 68.4 | Vol: 1.61 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:00:30] BTC | Mid: 86534.50 | SMA: 86451.78 | EMA: 86631.18 | Vol_RSI: 74.7 | Vol: 0.16 | Signal: FLAT | Position: 0
# [18:00:31] ETH | Mid: 2850.05 | SMA: 2851.36 | EMA: 2858.93 | Vol_RSI: 74.0 | Vol: 2.43 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:01:32] BTC | Mid: 86577.50 | SMA: 86457.02 | EMA: 86630.11 | Vol_RSI: 55.7 | Vol: 0.70 | Signal: FLAT | Position: 0
# [18:01:33] ETH | Mid: 2851.85 | SMA: 2851.38 | EMA: 2858.79 | Vol_RSI: 49.3 | Vol: 9.95 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:02:34] BTC | Mid: 86580.50 | SMA: 86461.96 | EMA: 86629.13 | Vol_RSI: 58.6 | Vol: 0.02 | Signal: FLAT | Position: 0
# [18:02:34] ETH | Mid: 2849.25 | SMA: 2851.29 | EMA: 2858.60 | Vol_RSI: 54.6 | Vol: 10.41 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:03:35] BTC | Mid: 86579.50 | SMA: 86466.48 | EMA: 86628.15 | Vol_RSI: 56.7 | Vol: 0.00 | Signal: FLAT | Position: 0
# [18:03:36] ETH | Mid: 2850.05 | SMA: 2851.25 | EMA: 2858.43 | Vol_RSI: 50.6 | Vol: 1.82 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:04:37] BTC | Mid: 86724.50 | SMA: 86476.04 | EMA: 86630.06 | Vol_RSI: 48.7 | Vol: 0.21 | Signal: FLAT | Position: 0
# [18:04:37] ETH | Mid: 2858.95 | SMA: 2851.53 | EMA: 2858.44 | Vol_RSI: 55.9 | Vol: 15.65 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:05:38] BTC | Mid: 86613.50 | SMA: 86480.95 | EMA: 86629.73 | Vol_RSI: 55.0 | Vol: 0.04 | Signal: FLAT | Position: 0
# [18:05:39] ETH | Mid: 2853.05 | SMA: 2851.59 | EMA: 2858.33 | Vol_RSI: 65.4 | Vol: 1.50 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:06:40] BTC | Mid: 86737.50 | SMA: 86489.79 | EMA: 86631.86 | Vol_RSI: 62.5 | Vol: 3.59 | Signal: FLAT | Position: 0
# [18:06:41] ETH | Mid: 2859.15 | SMA: 2851.85 | EMA: 2858.35 | Vol_RSI: 74.9 | Vol: 6.40 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:07:42] BTC | Mid: 86752.50 | SMA: 86498.55 | EMA: 86634.25 | Vol_RSI: 64.2 | Vol: 0.19 | Signal: FLAT | Position: 0
# [18:07:42] ETH | Mid: 2858.85 | SMA: 2852.08 | EMA: 2858.36 | Vol_RSI: 76.1 | Vol: 0.65 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:08:43] BTC | Mid: 86756.50 | SMA: 86506.87 | EMA: 86636.67 | Vol_RSI: 60.5 | Vol: 0.04 | Signal: FLAT | Position: 0
# [18:08:44] ETH | Mid: 2858.05 | SMA: 2852.27 | EMA: 2858.35 | Vol_RSI: 73.2 | Vol: 3.05 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:09:44] BTC | Mid: 86671.50 | SMA: 86512.02 | EMA: 86637.36 | Vol_RSI: 65.1 | Vol: 0.19 | Signal: FLAT | Position: 0
# [18:09:45] ETH | Mid: 2856.15 | SMA: 2852.39 | EMA: 2858.31 | Vol_RSI: 74.9 | Vol: 0.81 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:10:46] BTC | Mid: 86639.50 | SMA: 86515.88 | EMA: 86637.40 | Vol_RSI: 62.1 | Vol: 0.29 | Signal: FLAT | Position: 0
# [18:10:47] ETH | Mid: 2856.00 | SMA: 2852.50 | EMA: 2858.26 | Vol_RSI: 71.7 | Vol: 0.46 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:11:48] BTC | Mid: 86568.50 | SMA: 86517.43 | EMA: 86636.04 | Vol_RSI: 65.3 | Vol: 0.00 | Signal: FLAT | Position: 0
# [18:11:49] ETH | Mid: 2852.85 | SMA: 2852.51 | EMA: 2858.16 | Vol_RSI: 73.3 | Vol: 3.32 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:12:50] BTC | Mid: 86557.50 | SMA: 86518.57 | EMA: 86634.48 | Vol_RSI: 60.6 | Vol: 0.00 | Signal: FLAT | Position: 0
# [18:12:50] ETH | Mid: 2853.50 | SMA: 2852.54 | EMA: 2858.06 | Vol_RSI: 68.9 | Vol: 13.05 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:13:52] BTC | Mid: 86572.50 | SMA: 86520.07 | EMA: 86633.26 | Vol_RSI: 60.6 | Vol: 0.34 | Signal: FLAT | Position: 0
# [18:13:53] ETH | Mid: 2853.35 | SMA: 2852.56 | EMA: 2857.97 | Vol_RSI: 66.1 | Vol: 1.21 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:14:57] BTC | Mid: 86520.50 | SMA: 86520.08 | EMA: 86631.02 | Vol_RSI: 36.8 | Vol: 0.66 | Signal: FLAT | Position: 0
# [18:14:58] ETH | Mid: 2851.65 | SMA: 2852.54 | EMA: 2857.85 | Vol_RSI: 60.3 | Vol: 5.45 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:15:59] BTC | Mid: 86457.50 | SMA: 86518.43 | EMA: 86627.59 | Vol_RSI: 38.0 | Vol: 0.09 | Signal: FLAT | Position: 0
# [18:16:00] ETH | Mid: 2848.35 | SMA: 2852.43 | EMA: 2857.66 | Vol_RSI: 61.2 | Vol: 7.08 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:17:01] BTC | Mid: 86421.50 | SMA: 86515.95 | EMA: 86623.51 | Vol_RSI: 39.8 | Vol: 0.01 | Signal: FLAT | Position: 0
# [18:17:01] ETH | Mid: 2845.15 | SMA: 2852.24 | EMA: 2857.41 | Vol_RSI: 62.3 | Vol: 5.42 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:18:02] BTC | Mid: 86464.50 | SMA: 86514.66 | EMA: 86620.36 | Vol_RSI: 42.4 | Vol: 0.33 | Signal: FLAT | Position: 0
# [18:18:03] ETH | Mid: 2846.85 | SMA: 2852.11 | EMA: 2857.20 | Vol_RSI: 63.6 | Vol: 5.07 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:19:04] BTC | Mid: 86513.50 | SMA: 86514.63 | EMA: 86618.24 | Vol_RSI: 23.9 | Vol: 0.26 | Signal: FLAT | Position: 0
# [18:19:04] ETH | Mid: 2849.15 | SMA: 2852.04 | EMA: 2857.04 | Vol_RSI: 37.0 | Vol: 2.14 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:20:05] BTC | Mid: 86483.50 | SMA: 86513.89 | EMA: 86615.57 | Vol_RSI: 15.6 | Vol: 0.03 | Signal: FLAT | Position: 0
# [18:20:06] ETH | Mid: 2849.45 | SMA: 2851.97 | EMA: 2856.89 | Vol_RSI: 23.5 | Vol: 0.04 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:21:07] BTC | Mid: 86581.50 | SMA: 86515.47 | EMA: 86614.90 | Vol_RSI: 7.4 | Vol: 0.04 | Signal: FLAT | Position: 0
# [18:21:08] ETH | Mid: 2853.75 | SMA: 2852.02 | EMA: 2856.83 | Vol_RSI: 8.1 | Vol: 0.04 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:22:09] BTC | Mid: 86629.50 | SMA: 86518.06 | EMA: 86615.19 | Vol_RSI: 8.1 | Vol: 0.13 | Signal: FLAT | Position: 0
# [18:22:09] ETH | Mid: 2856.45 | SMA: 2852.12 | EMA: 2856.82 | Vol_RSI: 9.2 | Vol: 0.05 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:23:10] BTC | Mid: 86586.50 | SMA: 86519.58 | EMA: 86614.62 | Vol_RSI: 8.8 | Vol: 0.09 | Signal: FLAT | Position: 0
# [18:23:11] ETH | Mid: 2854.25 | SMA: 2852.16 | EMA: 2856.77 | Vol_RSI: 10.0 | Vol: 0.07 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:24:11] BTC | Mid: 86651.50 | SMA: 86522.45 | EMA: 86615.35 | Vol_RSI: 8.2 | Vol: 0.02 | Signal: FLAT | Position: 0
# [18:24:12] ETH | Mid: 2857.95 | SMA: 2852.29 | EMA: 2856.79 | Vol_RSI: 15.0 | Vol: 0.33 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:25:13] BTC | Mid: 86588.00 | SMA: 86523.84 | EMA: 86614.81 | Vol_RSI: 9.0 | Vol: 2.90 | Signal: FLAT | Position: 0
# [18:25:13] ETH | Mid: 2856.35 | SMA: 2852.38 | EMA: 2856.79 | Vol_RSI: 16.1 | Vol: 0.11 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:26:14] BTC | Mid: 86577.50 | SMA: 86524.96 | EMA: 86614.07 | Vol_RSI: 8.6 | Vol: 0.01 | Signal: FLAT | Position: 0
# [18:26:15] ETH | Mid: 2855.45 | SMA: 2852.44 | EMA: 2856.76 | Vol_RSI: 15.4 | Vol: 2.03 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:27:16] BTC | Mid: 86499.50 | SMA: 86524.44 | EMA: 86611.80 | Vol_RSI: 10.0 | Vol: 0.01 | Signal: FLAT | Position: 0
# [18:27:16] ETH | Mid: 2852.55 | SMA: 2852.44 | EMA: 2856.68 | Vol_RSI: 17.1 | Vol: 0.82 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:28:17] BTC | Mid: 86430.50 | SMA: 86522.56 | EMA: 86608.21 | Vol_RSI: 11.2 | Vol: 0.01 | Signal: FLAT | Position: 0
# [18:28:18] ETH | Mid: 2847.75 | SMA: 2852.35 | EMA: 2856.50 | Vol_RSI: 28.6 | Vol: 0.58 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:29:19] BTC | Mid: 86434.50 | SMA: 86520.83 | EMA: 86604.77 | Vol_RSI: 11.2 | Vol: 0.08 | Signal: FLAT | Position: 0
# [18:29:19] ETH | Mid: 2848.55 | SMA: 2852.27 | EMA: 2856.34 | Vol_RSI: 29.5 | Vol: 16.58 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:30:20] BTC | Mid: 86410.50 | SMA: 86518.71 | EMA: 86600.92 | Vol_RSI: 10.9 | Vol: 0.05 | Signal: FLAT | Position: 0
# [18:30:20] ETH | Mid: 2847.65 | SMA: 2852.18 | EMA: 2856.17 | Vol_RSI: 27.6 | Vol: 1.69 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:31:21] BTC | Mid: 86530.50 | SMA: 86518.93 | EMA: 86599.53 | Vol_RSI: 28.0 | Vol: 0.43 | Signal: FLAT | Position: 0
# [18:31:22] ETH | Mid: 2850.75 | SMA: 2852.16 | EMA: 2856.06 | Vol_RSI: 29.9 | Vol: 0.43 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:32:23] BTC | Mid: 86502.00 | SMA: 86518.62 | EMA: 86597.60 | Vol_RSI: 27.8 | Vol: 0.01 | Signal: FLAT | Position: 0
# [18:32:24] ETH | Mid: 2848.25 | SMA: 2852.09 | EMA: 2855.91 | Vol_RSI: 30.7 | Vol: 2.98 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# [18:33:25] BTC | Mid: 86512.50 | SMA: 86518.51 | EMA: 86595.91 | Vol_RSI: 27.1 | Vol: 0.04 | Signal: FLAT | Position: 0
# [18:33:25] ETH | Mid: 2849.15 | SMA: 2852.03 | EMA: 2855.77 | Vol_RSI: 29.5 | Vol: 2.61 | Signal: FLAT | Position: 0
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 48
#      45     break
#      47 print("-" * 80)
# ---> 48 time.sleep(LOOP_INTERVAL)
#
# KeyboardInterrupt:

# %%
from data.hyperliquid import fetch_orderbook

ob = fetch_orderbook("BTC")
ob
# Out:
# {'coin': 'BTC',
#  'time': 1766028055216,
#  'levels': [[{'px': '86441.0', 'sz': '2.176', 'n': 5},
#    {'px': '86440.0', 'sz': '0.14895', 'n': 3},
#    {'px': '86439.0', 'sz': '0.00013', 'n': 1},
#    {'px': '86438.0', 'sz': '0.05797', 'n': 2},
#    {'px': '86437.0', 'sz': '0.40521', 'n': 2},
#    {'px': '86436.0', 'sz': '0.05797', 'n': 2},
#    {'px': '86435.0', 'sz': '0.00013', 'n': 1},
#    {'px': '86434.0', 'sz': '0.00013', 'n': 1},
#    {'px': '86433.0', 'sz': '0.18301', 'n': 3},
#    {'px': '86432.0', 'sz': '4.18742', 'n': 8},
#    {'px': '86431.0', 'sz': '1.92082', 'n': 4},
#    {'px': '86430.0', 'sz': '0.41387', 'n': 3},
#    {'px': '86429.0', 'sz': '0.20066', 'n': 4},
#    {'px': '86428.0', 'sz': '1.80368', 'n': 3},
#    {'px': '86427.0', 'sz': '0.06811', 'n': 3},
#    {'px': '86426.0', 'sz': '1.86894', 'n': 4},
#    {'px': '86425.0', 'sz': '0.91031', 'n': 6},
#    {'px': '86424.0', 'sz': '0.07186', 'n': 3},
#    {'px': '86423.0', 'sz': '0.6599', 'n': 7},
#    {'px': '86422.0', 'sz': '0.51784', 'n': 5}],
#   [{'px': '86442.0', 'sz': '18.05693', 'n': 51},
#    {'px': '86443.0', 'sz': '2.53093', 'n': 4},
#    {'px': '86444.0', 'sz': '3.15063', 'n': 1},
#    {'px': '86445.0', 'sz': '0.05784', 'n': 1},
#    {'px': '86446.0', 'sz': '0.64637', 'n': 3},
#    {'px': '86447.0', 'sz': '0.96542', 'n': 5},
#    {'px': '86448.0', 'sz': '7.35522', 'n': 11},
#    {'px': '86449.0', 'sz': '0.32457', 'n': 7},
#    {'px': '86450.0', 'sz': '0.76211', 'n': 4},
#    {'px': '86451.0', 'sz': '1.61574', 'n': 5},
#    {'px': '86452.0', 'sz': '2.42868', 'n': 4},
#    {'px': '86453.0', 'sz': '15.60609', 'n': 5},
#    {'px': '86454.0', 'sz': '1.17241', 'n': 5},
#    {'px': '86455.0', 'sz': '0.13594', 'n': 4},
#    {'px': '86456.0', 'sz': '2.1101', 'n': 5},
#    {'px': '86457.0', 'sz': '7.73185', 'n': 4},
#    {'px': '86458.0', 'sz': '0.19346', 'n': 5},
#    {'px': '86459.0', 'sz': '1.47638', 'n': 5},
#    {'px': '86460.0', 'sz': '3.93391', 'n': 10},
#    {'px': '86461.0', 'sz': '3.14336', 'n': 5}]]}

# %%
type(ob), ob.keys()
# Out:
# (dict, dict_keys(['coin', 'time', 'levels']))

# %%
levels = ob["levels"]

type(levels), len(levels)
# Out:
# (list, 2)

# %%
levels
# Out:
# [[{'px': '86441.0', 'sz': '2.176', 'n': 5},
#   {'px': '86440.0', 'sz': '0.14895', 'n': 3},
#   {'px': '86439.0', 'sz': '0.00013', 'n': 1},
#   {'px': '86438.0', 'sz': '0.05797', 'n': 2},
#   {'px': '86437.0', 'sz': '0.40521', 'n': 2},
#   {'px': '86436.0', 'sz': '0.05797', 'n': 2},
#   {'px': '86435.0', 'sz': '0.00013', 'n': 1},
#   {'px': '86434.0', 'sz': '0.00013', 'n': 1},
#   {'px': '86433.0', 'sz': '0.18301', 'n': 3},
#   {'px': '86432.0', 'sz': '4.18742', 'n': 8},
#   {'px': '86431.0', 'sz': '1.92082', 'n': 4},
#   {'px': '86430.0', 'sz': '0.41387', 'n': 3},
#   {'px': '86429.0', 'sz': '0.20066', 'n': 4},
#   {'px': '86428.0', 'sz': '1.80368', 'n': 3},
#   {'px': '86427.0', 'sz': '0.06811', 'n': 3},
#   {'px': '86426.0', 'sz': '1.86894', 'n': 4},
#   {'px': '86425.0', 'sz': '0.91031', 'n': 6},
#   {'px': '86424.0', 'sz': '0.07186', 'n': 3},
#   {'px': '86423.0', 'sz': '0.6599', 'n': 7},
#   {'px': '86422.0', 'sz': '0.51784', 'n': 5}],
#  [{'px': '86442.0', 'sz': '18.05693', 'n': 51},
#   {'px': '86443.0', 'sz': '2.53093', 'n': 4},
#   {'px': '86444.0', 'sz': '3.15063', 'n': 1},
#   {'px': '86445.0', 'sz': '0.05784', 'n': 1},
#   {'px': '86446.0', 'sz': '0.64637', 'n': 3},
#   {'px': '86447.0', 'sz': '0.96542', 'n': 5},
#   {'px': '86448.0', 'sz': '7.35522', 'n': 11},
#   {'px': '86449.0', 'sz': '0.32457', 'n': 7},
#   {'px': '86450.0', 'sz': '0.76211', 'n': 4},
#   {'px': '86451.0', 'sz': '1.61574', 'n': 5},
#   {'px': '86452.0', 'sz': '2.42868', 'n': 4},
#   {'px': '86453.0', 'sz': '15.60609', 'n': 5},
#   {'px': '86454.0', 'sz': '1.17241', 'n': 5},
#   {'px': '86455.0', 'sz': '0.13594', 'n': 4},
#   {'px': '86456.0', 'sz': '2.1101', 'n': 5},
#   {'px': '86457.0', 'sz': '7.73185', 'n': 4},
#   {'px': '86458.0', 'sz': '0.19346', 'n': 5},
#   {'px': '86459.0', 'sz': '1.47638', 'n': 5},
#   {'px': '86460.0', 'sz': '3.93391', 'n': 10},
#   {'px': '86461.0', 'sz': '3.14336', 'n': 5}]]

# %%
bids = levels[0]
asks = levels[1]

print("BIDS type:", type(bids))
print("ASKS type:", type(asks))

print("First bid:", bids[0])
print("First ask:", asks[0])
# Out:
# BIDS type: <class 'list'>
# ASKS type: <class 'list'>
# First bid: {'px': '86441.0', 'sz': '2.176', 'n': 5}
# First ask: {'px': '86442.0', 'sz': '18.05693', 'n': 51}

# %%
type(bids[0]), bids[0]
# Out:
# (dict, {'px': '86441.0', 'sz': '2.176', 'n': 5})
